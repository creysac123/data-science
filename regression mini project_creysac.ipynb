# %% [markdown]
# ## $$Data \ analysis \ and \ prediction \ of \ Stores \ sales$$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt # for visualization

import seaborn as sns           # for visualization

from sklearn import preprocessing   # for machine learning
from sklearn.preprocessing import MinMaxScaler, StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# evaluation imports
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.tree import plot_tree
# enable inline plots in the notebook
# %matplotlib inline

# %% [markdown]
# ## Importing data:

# %%
df=pd.read_csv('DS3_C6_S1_Regression_StoreSales_Data_Project.csv')
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.074402
# 4           NCD19         8.93          Low Fat         0.064299
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                14204 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                14204 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.3+ MB

# %%
df.shape
# Out:
# (14204, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  14204.000000     14204.000000  14204.000000               14204.000000
# mean      12.793380         0.070301    141.004977                1997.830681
# std        4.651716         0.048621     62.086938                   8.371664
# min        4.555000         0.003575     31.290000                1985.000000
# 25%        8.710000         0.033143     94.012000                1987.000000
# 50%       12.600000         0.062347    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# Separating out the categorical and continuous variables
def seprate_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:                # looping on the number of columns
        if df[column].nunique() < 100:       # nunique:  returns unique values in the column,
                                                    #here 100 is the hyperparamter and can be changed
            categorical.append(column)
        else:
            continuous.append(column)
            
    return categorical, continuous 


categorical, continuous = seprate_data_types(df)         # Calling the function

# # Tabulate is a package used to print the list, dict or any data sets in a proper format; in table format
from tabulate import tabulate
table = [categorical, continuous]
print(tabulate({"Categorical":categorical,
                "continuous": continuous}, headers = ["categorical", "continuous"]))
# Out:
# categorical                continuous
# -------------------------  -----------------
# Item_Fat_Content           Item_Identifier
# Item_Type                  Item_Weight
# Outlet_Identifier          Item_Visibility
# Outlet_Establishment_Year  Item_MRP
# Outlet_Size                Item_Outlet_Sales
# Outlet_Location_Type
# Outlet_Type

# %% [markdown]
# # $$ Univariate\ Data \ Analysis$$

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {df[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe
    if df[col].isnull().sum() > 0:  # check if null values are present
        print(f"\nThere are null values in the {col} column")

# %% [markdown]
# ### Exploring feature: Item_Fat_Content

# %%
info_of_cat('Item_Fat_Content')
# Out:
# Unique values in Item_Fat_Content are: ['Low Fat' 'Regular']
# Mode of Item_Fat_Content is Low Fat
# Number of missing values in Item_Fat_Content is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Fat content")                  # Set the title of the graph
percentage = df["Item_Fat_Content"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Item_Fat_Content"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Item_Fat_Content"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Exploring features: Item type

# %%
info_of_cat("Item_Type")
# Out:
# Unique values in Item_Type are: ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# Mode of Item_Type is Fruits and Vegetables
# Number of missing values in Item_Type is 0

# %%
fig= plt.figure( figsize = (15, 5))
plt.title("Count of Item type")                  # Set the title of the graph
percentage = df["Item_Type"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Item_Type"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Item_Type"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Exploring feature: Outlet Identifier

# %%
info_of_cat("Outlet_Identifier")
# Out:
# Unique values in Outlet_Identifier are: ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
# Mode of Outlet_Identifier is OUT027
# Number of missing values in Outlet_Identifier is 0

# %%
fig= plt.figure( figsize = (15, 5))
plt.title("Count of Item type")                  # Set the title of the graph
percentage = df["Outlet_Identifier"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Outlet_Identifier"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Outlet_Identifier"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Exploring feature: Outlet establishment year.

# %%
info_of_cat("Outlet_Establishment_Year")
# Out:
# Unique values in Outlet_Establishment_Year are: [1999 2009 1998 1987 1985 2002 2007 1997 2004]
# Mode of Outlet_Establishment_Year is 1985
# Number of missing values in Outlet_Establishment_Year is 0

# %%
fig= plt.figure( figsize = (15, 5))
plt.title("Count of Item type")                  # Set the title of the graph
percentage = df["Outlet_Establishment_Year"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Outlet_Establishment_Year"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Outlet_Establishment_Year"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Exploring feature: Outlet size.

# %%
info_of_cat("Outlet_Size")
# Out:
# Unique values in Outlet_Size are: ['Medium' 'High' 'Small']
# Mode of Outlet_Size is Small
# Number of missing values in Outlet_Size is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Outlet size")                  # Set the title of the graph
percentage = df["Outlet_Size"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Outlet_Size"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Outlet_Size"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Exploring feature: Outlet location type

# %%
info_of_cat("Outlet_Location_Type")
# Out:
# Unique values in Outlet_Location_Type are: ['Tier 1' 'Tier 3' 'Tier 2']
# Mode of Outlet_Location_Type is Tier 3
# Number of missing values in Outlet_Location_Type is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (10, 7))
ax[0].set_title("Count of Outlet location")                  # Set the title of the graph
percentage = df["Outlet_Location_Type"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Outlet_Location_Type"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Outlet_Location_Type"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# ## Exploring feature: Outlet type

# %%
info_of_cat("Outlet_Type")
# Out:
# Unique values in Outlet_Type are: ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']
# Mode of Outlet_Type is Supermarket Type1
# Number of missing values in Outlet_Type is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Outlet location")                  # Set the title of the graph
percentage = df["Outlet_Type"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Outlet_Type"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Outlet_Type"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Numerical \ Variables$$

# %%
def info_of_numerical(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %% [markdown]
# ## Exploring feature: Item weight

# %%
info_of_numerical('Item_Weight')
# Out:
# The mean of the Item_Weight is 12.793380385807628
# The median of the Item_Weight is 12.6
# The mode of the Item_Weight is 17.6
# The standard deviation of the Item_Weight is 4.6517158036609825
# Number of missing values in the Item_Weight is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Item_Weight"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Item_Weight"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ## Exploring feature: Item visibility

# %%
info_of_numerical("Item_Visibility")
# Out:
# The mean of the Item_Visibility is 0.07030079341671354
# The median of the Item_Visibility is 0.062347052
# The mode of the Item_Visibility is 0.06470883
# The standard deviation of the Item_Visibility is 0.048621198376929964
# Number of missing values in the Item_Visibility is 0

# %%
# Distribution of AMT_INCOME_TOTAL
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Item_Visibility"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Item_Visibility"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ### Since we have a lot of outliers, we have to treat them.

# %%
df["Item_Visibility"].quantile(.95)
df["Item_Visibility"]=df["Item_Visibility"].clip(upper=df["Item_Visibility"].quantile(0.95))

# %%
# Distribution of AMT_INCOME_TOTAL
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Item_Visibility"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Item_Visibility"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ## Exploring feature: Item mrp

# %%
info_of_numerical("Item_MRP")
# Out:
# The mean of the Item_MRP is 141.00497725992656
# The median of the Item_MRP is 142.247
# The mode of the Item_MRP is 172.0422
# The standard deviation of the Item_MRP is 62.086938014763994
# Number of missing values in the Item_MRP is 0

# %%
# Distribution of AMT_INCOME_TOTAL
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Item_MRP"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Item_MRP"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ## Exploring feature: Item outlet sales

# %%
info_of_numerical("Item_Outlet_Sales")
# Out:
# The mean of the Item_Outlet_Sales is 2181.2889135750365
# The median of the Item_Outlet_Sales is 1794.331
# The mode of the Item_Outlet_Sales is 958.752
# The standard deviation of the Item_Outlet_Sales is 1706.499615733832
# Number of missing values in the Item_Outlet_Sales is 5681

# %%
# Distribution of AMT_INCOME_TOTAL
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Item_Outlet_Sales"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Item_Outlet_Sales"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %% [markdown]
# ### Outlier treatment:

# %%
df["Item_Outlet_Sales"].quantile(.95)
df["Item_Outlet_Sales"]=df["Item_Outlet_Sales"].clip(upper=df["Item_Outlet_Sales"].quantile(0.95))

# %%
# Distribution of AMT_INCOME_TOTAL
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["Item_Outlet_Sales"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["Item_Outlet_Sales"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
df1=df.copy()
columns=df1.columns

# %% [markdown]
# ## Converting the category types:

# %%
# Converting non-numeric labeled column into categorical column
df1['Item_Fat_Content']=df1['Item_Fat_Content'].astype('category')
df1['Item_Type']=df1['Item_Type'].astype('category')
df1['Outlet_Identifier']=df1['Outlet_Identifier'].astype('category')
df1['Outlet_Establishment_Year']=df1['Outlet_Establishment_Year'].astype('category')
df1['Outlet_Size']=df1['Outlet_Size'].astype('category')
df1['Outlet_Location_Type']=df1['Outlet_Location_Type'].astype('category')
df1['Outlet_Type']=df1['Outlet_Type'].astype('category')
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.074402
# 4           NCD19         8.93          Low Fat         0.064299
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# 3                      1998      Medium               Tier 3
# 4                      1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df1.dtypes
# Out:
# Item_Identifier                object
# Item_Weight                   float64
# Item_Fat_Content             category
# Item_Visibility               float64
# Item_Type                    category
# Item_MRP                      float64
# Outlet_Identifier            category
# Outlet_Establishment_Year    category
# Outlet_Size                  category
# Outlet_Location_Type         category
# Outlet_Type                  category
# Item_Outlet_Sales             float64
# dtype: object

# %% [markdown]
# ## Label encoding:

# %%
# Using Label Encoder technique to convert categorical column into numerical type

#label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'species'.
df1['Item_Fat_Content_encode']= label_encoder.fit_transform(df1['Item_Fat_Content'])
 
df1['Item_Fat_Content_encode'].unique()
# Out:
# array([0, 1])

# %%
df1['Item_Type_encode']= label_encoder.fit_transform(df1['Item_Type'])
 
df1['Item_Type_encode'].unique()
# Out:
# array([ 4, 14, 10,  6,  9,  0, 13,  5,  2,  8,  7,  3,  1, 15, 11, 12])

# %%
# Using Label Encoder technique to convert categorical column into numerical type

#label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'species'.
df1['Outlet_Identifier_encode']= label_encoder.fit_transform(df1['Outlet_Identifier'])
 
df1['Outlet_Identifier_encode'].unique()
# Out:
# array([9, 3, 0, 1, 5, 7, 2, 8, 6, 4])

# %%
df1['Outlet_Establishment_Year_encode']= label_encoder.fit_transform(df1['Outlet_Establishment_Year'])
 
df1['Outlet_Establishment_Year_encode'].unique()
# Out:
# array([4, 8, 3, 1, 0, 5, 7, 2, 6], dtype=int64)

# %%
df1['Outlet_Size_encode']= label_encoder.fit_transform(df1['Outlet_Size'])
 
df1['Outlet_Size_encode'].unique()
# Out:
# array([1, 0, 2])

# %%
df1['Outlet_Location_Type_encode']= label_encoder.fit_transform(df1['Outlet_Location_Type'])
 
df1['Outlet_Location_Type_encode'].unique()
# Out:
# array([0, 2, 1])

# %%
df1['Outlet_Type_encode']= label_encoder.fit_transform(df1['Outlet_Type'])
 
df1['Outlet_Type_encode'].unique()
# Out:
# array([1, 2, 0, 3])

# %% [markdown]
# ## Scaling:

# %%
# Defining method to perform data scaling operation based on the type of scaling
def feature_scale(scale):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    new_sales_df_c = df1.select_dtypes(include='number')
    if scale == 'minmax':
        scaler = MinMaxScaler()
    else:
        scaler = StandardScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(new_sales_df_c.to_numpy()),columns=new_sales_df_c.columns)
    return df_scaled

# %%
scale = 'minmax' #standard
sales_df_scaled=feature_scale(scale)
sales_df_scaled
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  \
# 0         0.282525         0.078093  0.927507           0.674348
# 1         0.081274         0.098322  0.072068           0.074712
# 2         0.770765         0.082556  0.468288           0.375985
# 3         0.871986         0.443464  0.640093           0.127350
# 4         0.260494         0.380205  0.095805           0.175136
# ...            ...              ...       ...                ...
# 14199     0.353974         0.062122  0.467004                NaN
# 14200     0.181304         0.872908  0.585126                NaN
# 14201     0.324204         0.437993  0.371199                NaN
# 14202     0.639774         0.382771  0.778154                NaN
# 14203     0.294433         0.633288  0.205884                NaN
#
#        Item_Fat_Content_encode  Item_Type_encode  Outlet_Identifier_encode  \
# 0                          0.0          0.266667                  1.000000
# 1                          1.0          0.933333                  0.333333
# 2                          0.0          0.666667                  1.000000
# 3                          1.0          0.400000                  0.000000
# 4                          0.0          0.600000                  0.111111
# ...                        ...               ...                       ...
# 14199                      1.0          0.866667                  0.888889
# 14200                      1.0          1.000000                  0.333333
# 14201                      0.0          0.533333                  0.777778
# 14202                      1.0          0.200000                  0.222222
# 14203                      1.0          0.200000                  0.777778
#
#        Outlet_Establishment_Year_encode  Outlet_Size_encode  \
# 0                                 0.500                 0.5
# 1                                 1.000                 0.5
# 2                                 0.500                 0.5
# 3                                 0.375                 0.5
# 4                                 0.125                 0.0
# ...                                 ...                 ...
# 14199                             0.250                 1.0
# 14200                             1.000                 0.5
# 14201                             0.625                 1.0
# 14202                             0.875                 1.0
# 14203                             0.625                 1.0
#
#        Outlet_Location_Type_encode  Outlet_Type_encode
# 0                              0.0            0.333333
# 1                              1.0            0.666667
# 2                              0.0            0.333333
# 3                              1.0            0.000000
# 4                              1.0            0.333333
# ...                            ...                 ...
# 14199                          0.0            0.333333
# 14200                          1.0            0.666667
# 14201                          0.5            0.333333
# 14202                          0.5            0.333333
# 14203                          0.5            0.333333
#
# [14204 rows x 11 columns]

# %% [markdown]
# ## Correlation:

# %%
# Finding correlation among numerical features, based on their strong relation we can choose the important features
corr=sales_df_scaled.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4ebc5_row0_col0, #T_4ebc5_row1_col1, #T_4ebc5_row2_col2, #T_4ebc5_row3_col3, #T_4ebc5_row4_col4, #T_4ebc5_row5_col5, #T_4ebc5_row6_col6, #T_4ebc5_row7_col7, #T_4ebc5_row8_col8, #T_4ebc5_row9_col9, #T_4ebc5_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4ebc5_row0_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_4ebc5_row0_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_4ebc5_row0_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_4ebc5_row0_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_4ebc5_row0_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_4ebc5_row0_col6, #T_4ebc5_row4_col9, #T_4ebc5_row5_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_4ebc5_row0_col7, #T_4ebc5_row2_col7, #T_4ebc5_row4_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_4ebc5_row0_col8, #T_4ebc5_row8_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_4ebc5_row0_col9, #T_4ebc5_row2_col6, #T_4ebc5_row2_col9, #T_4ebc5_row4_col6, #T_4ebc5_row5_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_4ebc5_row0_col10, #T_4ebc5_row5_col10, #T_4ebc5_row10_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_4ebc5_row1_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4ebc5_row1_col2, #T_4ebc5_row1_col3, #T_4ebc5_row1_col7, #T_4ebc5_row4_col0, #T_4ebc5_row4_col2, #T_4ebc5_row4_col5, #T_4ebc5_row5_col4, #T_4ebc5_row6_col9, #T_4ebc5_row8_col10, #T_4ebc5_row9_col6, #T_4ebc5_row9_col8, #T_4ebc5_row10_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4ebc5_row1_col4, #T_4ebc5_row7_col10 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_4ebc5_row1_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_4ebc5_row1_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_4ebc5_row1_col8 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_4ebc5_row1_col9 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_4ebc5_row1_col10 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_4ebc5_row2_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_4ebc5_row2_col1, #T_4ebc5_row9_col7 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_4ebc5_row2_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_4ebc5_row2_col4, #T_4ebc5_row4_col3, #T_4ebc5_row6_col4, #T_4ebc5_row7_col4, #T_4ebc5_row8_col4, #T_4ebc5_row8_col5, #T_4ebc5_row10_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_4ebc5_row2_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_4ebc5_row2_col8, #T_4ebc5_row4_col8, #T_4ebc5_row5_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_4ebc5_row2_col10, #T_4ebc5_row4_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_4ebc5_row3_col0, #T_4ebc5_row6_col1, #T_4ebc5_row6_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4ebc5_row3_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_4ebc5_row3_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_4ebc5_row3_col4, #T_4ebc5_row3_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_4ebc5_row3_col6, #T_4ebc5_row3_col10 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_4ebc5_row3_col7, #T_4ebc5_row8_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_4ebc5_row3_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_4ebc5_row3_col9, #T_4ebc5_row10_col3 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_4ebc5_row4_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_4ebc5_row5_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_4ebc5_row5_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4ebc5_row5_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_4ebc5_row5_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_4ebc5_row5_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_4ebc5_row6_col0, #T_4ebc5_row10_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_4ebc5_row6_col2, #T_4ebc5_row7_col2, #T_4ebc5_row8_col2, #T_4ebc5_row10_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4ebc5_row6_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_4ebc5_row6_col5, #T_4ebc5_row7_col5, #T_4ebc5_row9_col4, #T_4ebc5_row9_col5, #T_4ebc5_row10_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_4ebc5_row6_col8 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_4ebc5_row6_col10 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_4ebc5_row7_col0, #T_4ebc5_row8_col0, #T_4ebc5_row10_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_4ebc5_row7_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4ebc5_row7_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_4ebc5_row7_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_4ebc5_row7_col8, #T_4ebc5_row9_col10 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_4ebc5_row7_col9 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_4ebc5_row8_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_4ebc5_row8_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_4ebc5_row8_col6 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_4ebc5_row9_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_4ebc5_row9_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_4ebc5_row9_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4ebc5_row9_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_4ebc5_row10_col6 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_4ebc5_row10_col9 {
#   background-color: #f7b093;
#   color: #000000;
# }
# </style>
# <table id="T_4ebc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ebc5_level0_col0" class="col_heading level0 col0" >Item_Weight</th>
#       <th id="T_4ebc5_level0_col1" class="col_heading level0 col1" >Item_Visibility</th>
#       <th id="T_4ebc5_level0_col2" class="col_heading level0 col2" >Item_MRP</th>
#       <th id="T_4ebc5_level0_col3" class="col_heading level0 col3" >Item_Outlet_Sales</th>
#       <th id="T_4ebc5_level0_col4" class="col_heading level0 col4" >Item_Fat_Content_encode</th>
#       <th id="T_4ebc5_level0_col5" class="col_heading level0 col5" >Item_Type_encode</th>
#       <th id="T_4ebc5_level0_col6" class="col_heading level0 col6" >Outlet_Identifier_encode</th>
#       <th id="T_4ebc5_level0_col7" class="col_heading level0 col7" >Outlet_Establishment_Year_encode</th>
#       <th id="T_4ebc5_level0_col8" class="col_heading level0 col8" >Outlet_Size_encode</th>
#       <th id="T_4ebc5_level0_col9" class="col_heading level0 col9" >Outlet_Location_Type_encode</th>
#       <th id="T_4ebc5_level0_col10" class="col_heading level0 col10" >Outlet_Type_encode</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ebc5_level0_row0" class="row_heading level0 row0" >Item_Weight</th>
#       <td id="T_4ebc5_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_4ebc5_row0_col1" class="data row0 col1" >-0.019416</td>
#       <td id="T_4ebc5_row0_col2" class="data row0 col2" >0.035751</td>
#       <td id="T_4ebc5_row0_col3" class="data row0 col3" >0.011997</td>
#       <td id="T_4ebc5_row0_col4" class="data row0 col4" >-0.033737</td>
#       <td id="T_4ebc5_row0_col5" class="data row0 col5" >0.031884</td>
#       <td id="T_4ebc5_row0_col6" class="data row0 col6" >0.003002</td>
#       <td id="T_4ebc5_row0_col7" class="data row0 col7" >0.000301</td>
#       <td id="T_4ebc5_row0_col8" class="data row0 col8" >0.000944</td>
#       <td id="T_4ebc5_row0_col9" class="data row0 col9" >-0.001719</td>
#       <td id="T_4ebc5_row0_col10" class="data row0 col10" >0.001913</td>
#     </tr>
#     <tr>
#       <th id="T_4ebc5_level0_row1" class="row_heading level0 row1" >Item_Visibility</th>
#       <td id="T_4ebc5_row1_col0" class="data row1 col0" >-0.019416</td>
#       <td id="T_4ebc5_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4ebc5_row1_col2" class="data row1 col2" >-0.007111</td>
#       <td id="T_4ebc5_row1_col3" class="data row1 col3" >-0.119324</td>
#       <td id="T_4ebc5_row1_col4" class="data row1 col4" >0.0

# %%
plt.figure(figsize=(10,8))
sns.heatmap(sales_df_scaled.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Histogram of all numerical features.

# %%
# Histogram of all numerical features

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

new_df = df1.select_dtypes(include='number')
numeric_cols=df1.columns
num_cols=5
n_bins = 20

# compute number of rows for plot 
num_rows= int(len(numeric_cols)/num_cols)

# setting canvas for plotting
fig, axs = plt.subplots(num_rows, num_cols, tight_layout=True,figsize=(20,10))

# plotting the numerical columns
for col, ax in zip(numeric_cols,axs.flatten()[:len(numeric_cols)]):
    ax.hist(df1[col],bins=n_bins,density=True)
    ax.set_title(col)

plt.show()

# %% [markdown]
# ## Histogram of categorical features:

# %%
# Histogram of all categorical features
num_cols = 3
cat_sal = df1.select_dtypes('category')
categorical_cols=cat_sal.columns
# compute number of rows for plot 
num_rows= int(len(categorical_cols)/num_cols)

# setting canvas for plotting
fig, axs = plt.subplots(num_rows, num_cols, tight_layout=True,figsize=(20,5))

# plotting the numerical columns
for col, ax in zip(categorical_cols,axs.flatten()[:len(categorical_cols)]):
    stats = cat_sal[col].value_counts()
    values = list(stats)
    names = list(map(lambda x : ''.join(('value_',str(x))),list(stats.index)))
    ax.bar(names,values)
    ax.set_title(col)
    
plt.show()

# %% [markdown]
# ## Splitting data into train and test.

# %%
df2=df1.select_dtypes('number')

# %%
train=df2[~df2['Item_Outlet_Sales'].isnull()]
test=df2[df2['Item_Outlet_Sales'].isnull()]

# %%
train.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  \
# 0         9.30         0.016047  249.8092          3735.1380
# 1         5.92         0.019278   48.2692           443.4228
# 2        17.50         0.016760  141.6180          2097.2700
# 3        19.20         0.074402  182.0950           732.3800
# 4         8.93         0.064299   53.8614           994.7052
#
#    Item_Fat_Content_encode  Item_Type_encode  Outlet_Identifier_encode  \
# 0                        0                 4                         9
# 1                        1                14                         3
# 2                        0                10                         9
# 3                        1                 6                         0
# 4                        0                 9                         1
#
#    Outlet_Establishment_Year_encode  Outlet_Size_encode  \
# 0                                 4                   1
# 1                                 8                   1
# 2                                 4                   1
# 3                                 3                   1
# 4                                 1                   0
#
#    Outlet_Location_Type_encode  Outlet_Type_encode
# 0                            0                   1
# 1                            2                   2
# 2                            0                   1
# 3                            2                   0
# 4                            2                   1

# %% [markdown]
# ## Linear regression:

# %%
x_train=train.loc[:,train.columns!='Item_Outlet_Sales']
y_train=train['Item_Outlet_Sales']

# %%
x_test=test.loc[:,test.columns!='Item_Outlet_Sales']
y_test=test['Item_Outlet_Sales']

# %%
reg = LinearRegression()
# Fit the regression with the scaled TRAIN inputs and targets
model=reg.fit(x_train,y_train)

# %%
model.intercept_
# Out:
# -796.920790610623

# %%
model.coef_
# Out:
# array([-9.35369922e-01, -1.67694996e+03,  1.43048066e+01,  6.02672754e+01,
#        -2.32121691e-01,  5.73527677e+01,  1.39067392e+01, -8.92724148e+01,
#        -1.09760514e+02,  7.76623736e+02])

# %%
model.score(x_train,y_train)
# Out:
# 0.5147488642895343

# %%
print("The equation of model for  sales is: y = %f x + %f"%(model.coef_[0] ,model.intercept_  ))
# Out:
# The equation of model for  sales is: y = -0.935370 x + -796.920791

# %%
predict=model.predict(x_test)
predict
# Out:
# array([1970.0679521 , 1139.67709293, 2211.05546948, ..., 1726.49624067,
#        2910.31994143, 1178.94146472])

# %%
dfpr = pd.DataFrame(predict, columns=['Prediction'])
dfpr.head(6)
# Out:
#     Prediction
# 0  1970.067952
# 1  1139.677093
# 2  2211.055469
# 3  2085.516326
# 4  4709.268314
# 5  1906.280048

# %% [markdown]
# ## Decision Tree Regressor:

# %%
from sklearn import metrics
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_val_predict, train_test_split
from sklearn import tree

# %%
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)

dtm.fit(x_train,y_train)
print("R-Squared on train dataset={}".format(dtm.score(x_train,y_train)))
# Out:
# R-Squared on train dataset=0.6020076243296916

# %%
# Setting dpi = 300 to make image clearer than default
fig, axes = plt.subplots(dpi=300)

tree.plot_tree(dtm,
           filled = True);

#save figure in current directory as png
fig.savefig('Bike_regression_decisiontree.png')

# %%
y_dec_pred = dtm.predict(x_test)

# %%
df_dt = pd.DataFrame(y_dec_pred, columns=['Prediction'])
df_dt.head()
# Out:
#     Prediction
# 0  1715.825320
# 1  1715.825320
# 2   471.306847
# 3  2767.099057
# 4  4774.333330

# %% [markdown]
# ## Random forest:

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor(n_estimators=100,criterion='squared_error',random_state=1,n_jobs=-1)
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=1)

# %%
forest.score(x_train,y_train)
# Out:
# 0.9413701064319908

# %%
y_pred_rf=forest.predict(x_test)

# %%
df_dt = pd.DataFrame(y_pred_rf, columns=['Prediction'])
df_dt.head()
# Out:
#     Prediction
# 0  1716.958382
# 1  1202.221744
# 2   648.589070
# 3  2179.003608
# 4  5142.579278

# %%
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
# Instantiate the grid search model
from sklearn.model_selection import GridSearchCV

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=forest,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="r2")

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# GridSearchCV(cv=4, estimator=RandomForestRegressor(n_jobs=-1, random_state=1),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='r2', verbose=1)

# %%
grid_search.best_score_
# Out:
# 0.6150108510831545

# %%
rf_best = grid_search.best_estimator_
rf_best
# Out:
# RandomForestRegressor(max_depth=5, min_samples_leaf=10, n_jobs=-1,
#                       random_state=1)

# %%
y_pred_rf1=model.predict(x_test)
df_rf1 = pd.DataFrame(y_pred_rf1, columns=['Prediction'])
df_rf1.head()
# Out:
#     Prediction
# 0  1970.067952
# 1  1139.677093
# 2  2211.055469
# 3  2085.516326
# 4  4709.268314

# %% [markdown]
# ## Comparison:

# %%
print('linear regression score:',model.score(x_train,y_train))
print('Decision tree score:',dtm.score(x_train,y_train))
print('Random forest score without hyperparameter tuning:',forest.score(x_train,y_train))
print('Random forest with hyperparameter tuning:',grid_search.best_score_)
# Out:
# linear regression score: 0.5147488642895343
# Decision tree score: 0.6020076243296916
# Random forest score without hyperparameter tuning: 0.9413701064319908
# Random forest with hyperparameter tuning: 0.6150108510831545

# %% [markdown]
# ### After checking the scores of 3 different models, random forest model without hyperparameter tuning gives the best score.
